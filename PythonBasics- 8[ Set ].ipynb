# %% [markdown]
# <a href="https://colab.research.google.com/github/DhirajBembade/Python/blob/main/PythonBasics-%208%5B%20Set%20%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SET - Data Structure**
#
# 1. If we want to represent a group of unique values as a single entity then we should go
# for set.
# 2. **Duplicates are not allowed.**
# 3. Insertion order is not preserved.But we can sort the elements.
# 4. **Indexing and slicing not allowed for the set.**
# 5. Heterogeneous elements are allowed.
# 6. Set objects are **mutable** i.e once we creates set object we can perform any changes in
# that object based on our requirement.
# 7. We can represent set elements within curly braces and with comma seperation
# 8. We can apply mathematical operations like union, intersection, difference etc on set
# objects.
#
# **SET:**
#
# * Sets are used to store multiple items in a single variable.
#
# * Set is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.
#
# * A set is a collection which is unordered, unchangeable*, and unindexed.
#
# * Note: Set items are unchangeable, but you can remove items and add new items.
#
# * Sets are written with curly brackets. **{}**
#
# * **Note: Sets are unordered, so you cannot be sure in which order the items will appear.**
#
#
# rev:
#
# ![image.png](data:image/png;base64,...)

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
print(type(thisset))
# Out:
# {'banana', 'apple', 'cherry'}
# <class 'set'>

# %%
s={10,20,30,40}
print(s)
print(type(s))
# Out:
# {40, 10, 20, 30}
# <class 'set'>

# %%
#We can create set objects by using set() Function s = set(any sequence)
l=[10,20,30,40,10,20,10]
s=set(l)
print(s)#{40,10,20,30}
# Out:
# {40, 10, 20, 30}

# %%
s=set(range(5))
print(s)#{0,1,2,3,4}
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# # Important Functions of Set:

# %%
# 1) add(x): add item x to the set
s={10,20,30}
s.add(40);
print(s)#{40,10,20,30}
# Out:
# {40, 10, 20, 30}

# %%
# 2)  update(x,y,z): add multiple items to the set
s={10,20,30}
l=[40,50,60,10]
s.update(l,range(5))
print(s)
# Out:
# {0, 1, 2, 3, 4, 40, 10, 50, 20, 60, 30}

# %% [markdown]
# Q) What is the difference between add() and update()
# Functions in Set?
#
# * **We can use add() to add individual item to the Set, where as we can use update () function to add multiple items to Set.**
#
# * **add() function can take only one argument where as update() function can take any number of arguments.**

# %% [markdown]
# **To add one item to a set use the add() method-**
#
# * Once a set is created, you cannot change its items, but you can add new items.
#
# Example
#
# Add an item to a set, using the **add()** method:

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'banana', 'apple', 'cherry', 'orange'}

# %% [markdown]
# **Add Any Iterable-**
#
# The object in the **update()** method does not have to be a set, it can be any iterable object (tuples, lists, dictionaries etc.).
#
# Example
# Add elements of a list to at set:

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'kiwi', 'apple', 'cherry', 'banana', 'orange'}

# %% [markdown]
# **Remove Item-**
#
# To remove an item in a set, use the **remove()**, or the **discard()** method.
#
# Note: If the item to remove does not exist, remove() will raise an error.
#
# Note: If the item to remove does not exist, discard() will NOT raise an error.
#
# * You can also use the **pop()** method to remove an item, but this method will **remove the last item**. Remember that ***sets are unordered***, so you will not know what item that gets removed.
#
# The return value of the pop() method is the removed item.
#
#
# Note: Sets are unordered, so when using the pop() method, you do not know which item that gets removed.
#
# **Clear Method**-
#
# **del Method**  - Delete Set completely

# %%
#Example
#Remove "banana" by using the remove() method:

thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")
print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
#Example
#Remove "banana" by using the discard() method:

thisset = {"apple", "banana", "cherry"}

thisset.discard("banana")

print(thisset)
# Out:
# {'apple', 'cherry'}

# %%
#Example
#Remove the last item by using the pop() method:

thisset = {"apple", "banana", "cherry"}

x = thisset.pop()

print(x)

print(thisset)
# Out:
# banana
# {'apple', 'cherry'}

# %%
#Example
#The clear() method empties the set:

thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %%
#Example
#he del keyword will delete the set completely:
thisset = {"apple", "banana", "cherry"}

del thisset

print(thisset)  ##this will raise an error because the set no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-3ece8605a7ab> in <module>
#       5 del thisset
#       6
# ----> 7 print(thisset)  ##this will raise an error because the set no longer exists
#
# NameError: name 'thisset' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# REV:
# ![image.png](data:image/png;base64,...)

# %%
#3. copy(): returns copy of the set(cloning)
s={10,20,30}
s1=s.copy()
print(s1)
# Out:
# {10, 20, 30}

# %%
#4. pop(): It removes and returns some random element from the set
s={40,10,30,20}
print(s)
print(s.pop())
print(s)
# Out:
# {40, 10, 20, 30}
# 40
# {10, 20, 30}

# %%
#5. remove(x):removes specified item from the set
s={40,10,30,20}
s.remove(30)
print(s)
# Out:
# {40, 10, 20}

# %%
#6.  discard(): It removes specified element from the space
# If specified error not present in the set then it will not throw error
s={40,10,30,20}
s.discard(30)
print(s)
# Out:
# {40, 10, 20}

# %%
#7. clear(): to remove all the elements from the set
s={10,20,30}
print(s)
s.clear()
print(s)
# Out:
# {10, 20, 30}
# set()

# %% [markdown]
# # **IMPORTANT CONCEPTS**
#
# # Mathematical Operations on the Set:

# %%
#1. union(): 
# Syntax: x.union(y) OR x|y: Return all the elements present in both sets
x={10,20,30,40}
y={30,40,50,60}
print(x.union(y))#{10,20,30,40,50,60}
print (x|y)#{10, 20, 30, 40, 50, 60}
# Out:
# {40, 10, 50, 20, 60, 30}
# {40, 10, 50, 20, 60, 30}

# %%
# 2. intersection():
#Syntax: x.intersection(y) or x&y
#Returns common elements present in both x and y
x={10,20,30,40}
y={30,40,50,60}
print(x.intersection(y))#{40,30}
print(x&y)#{40, 30}
# Out:
# {40, 30}
# {40, 30}

# %%
# 3. difference():
# Syntax: x.difference(y) OR x-y.
#Returns the elements present in x but not in y.
x={10,20,30,40}
y={30,40,50,60}
print(x.difference(y))#10, 20
print(x-y)#{10, 20}
print(y-x)#{50, 60}
# Out:
# {10, 20}
# {10, 20}
# {50, 60}

# %%
#4. symmetric_difference():
# x.symmetric_difference(y) OR x^y
#Returns elements present in either x OR y but not in both.
x={10,20,30,40}
y={30,40,50,60}
print(x.symmetric_difference(y))#{10,50,20,60}
print(x^y)#{10, 50, 20, 60}
# Out:
# {10, 50, 20, 60}
# {10, 50, 20, 60}

# %% [markdown]
# # Membership Operators: (in, not in)

# %%
s=set("python")
print(s)
print('d'in s)
print('p'in s)
# Out:
# {'t', 'h', 'o', 'p', 'y', 'n'}
# False
# True

# %% [markdown]
# # Set Comprehension:

# %%
#Set comprehension is possible.
s = {x*x for x in range(5)}   #where x*x- Square/multiplication
print(s)#{0,1,4,9,16}
# Out:
# {0, 1, 4, 9, 16}

# %% [markdown]
# # Set Objects won't support indexing and slicing:
#
# Bcoz - Insertion order is not preserved.

# %%
s={10,20,30,40}
print(s[0])# TypeError:'set'objectdoesnotsupportindexing
print(s[1:3])# TypeError: 'set' object is not subscriptable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-8176d88c9bbe> in <module>()
#       1 s={10,20,30,40}
# ----> 2 print(s[0])# TypeError:'set'objectdoesnotsupportindexing
#       3 print(s[1:3])# TypeError: 'set' object is not subscriptable
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ---

# %% [markdown]
# # Homework
#  Q) Write a Program to eliminate Duplicates Present in the
#   List?
#
# Q) Write a Program to Print different Vowels Present in the
#   given Word?(Using intersection method

# %%
 # Q) Write a Program to eliminate Duplicates Present in the List?
 
mylist = [10, 20, 30, 20, 10, 50, 60, 40, 80, 50, 40]
mylist = list(dict.fromkeys(mylist))

print(mylist)
# Out:
# [10, 20, 30, 50, 60, 40, 80]

# %%
l = ["apple", "banana", "apple", "cherry", "mango", "mango", "cherry"]
l = list(dict.fromkeys(l))

print(l)
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
def my_function(x):
  return list(dict.fromkeys(x))

mylist = my_function([10, 20, 30, 20, 10, 50, 60, 40, 80, 50, 40])

print(mylist)
# Out:
# [10, 20, 30, 50, 60, 40, 80]

# %%
mylist = ["apple", "banana", "apple", "cherry", "mango", "mango", "cherry"]

def my_function(x):
  return list(dict.fromkeys(x))

  mylist = my_function(mylist = ["apple", "banana", "apple", "cherry", "mango", "mango", "cherry"])

  print(mylist)

# %%
a = [10, 20, 30, 20, 10, 50, 60, 40, 80, 50, 40]
dup_items = set()
uniq_items = []
for x in a:
   if x not in dup_items:
      uniq_items.append(x)
      dup_items.add(x)

print(dup_items)
# Out:
# {40, 10, 80, 50, 20, 60, 30}

# %%
# Q) Write a Program to Print different Vowels Present in the
  # given Word?(Using intersection method )

vowels =['a','e','i','o','u']
elem = input("Enter any statement : ")
data = set(elem)
result = data.intersection(vowels)
print("Vowels present in given statement :",result)
# Out:
# Enter any statement : python is easy to learn
# Vowels present in given statement : {'i', 'o', 'a', 'e'}

# %%
# another method
elem = input("Enter any statement : ")
vowels =['a','e','i','o','u']
list1=[]
for x in elem:
    if (x in vowels and x not in list1):
        list1.append(x)
print("Vowels present in given statement : ",list1)
# Out:
# Enter any statement : python is easy to learn
# Vowels present in given statement :  ['o', 'i', 'e', 'a']
