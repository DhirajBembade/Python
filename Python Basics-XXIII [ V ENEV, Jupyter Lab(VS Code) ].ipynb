# %% [markdown]
# <a href="https://colab.research.google.com/github/DhirajBembade/Python/blob/main/Python%20Basics-XXIII%20%5B%20V%20ENEV%2C%20Jupyter%20Lab(VS%20Code)%20%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2022-12-21 175533.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2022-12-21 175515.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2022-12-21 180036.png](data:image/png;base64,...)
